# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import gc

import numpy as np
from matplotlib import pyplot as plt
import matplotlib.cm as cm

import pickle

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D
from tensorflow.keras import Input
from tensorflow.keras.layers import Dropout, BatchNormalization
from sklearn.model_selection import train_test_split
import cv2
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
# dir(tf.keras.applications)

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %% [markdown]
# > ### 증식 전후 데이터 로드

# %%
with open('/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/이미지 분류 미니프로젝트/4. Zero Centering & Type Casting & Augmentation/x_original.pickle', 'rb') as f:
    x_original = pickle.load(f)

with open('/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/이미지 분류 미니프로젝트/4. Zero Centering & Type Casting & Augmentation/y_original.pickle', 'rb') as f:
    y_original = pickle.load(f)

# %%
with open('/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/이미지 분류 미니프로젝트/4. Zero Centering & Type Casting & Augmentation/x_augmented.pickle', 'rb') as f:
    x_augmented = pickle.load(f)

with open('/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/이미지 분류 미니프로젝트/4. Zero Centering & Type Casting & Augmentation/y_augmented.pickle', 'rb') as f:
    y_augmented = pickle.load(f)

# %%
x_original.shape
# Out:
# (4052, 256, 256, 3)

# %%
x_augmented.shape
# Out:
# (8104, 256, 256, 3)

# %% [markdown]
# > ### 증식 전후 데이터 통합

# %%
x = np.concatenate((x_original, x_augmented), axis=0)
y = np.concatenate((y_original, y_augmented), axis=0)

# %%
x.shape, y.shape
# Out:
# ((12156, 256, 256, 3), (12156, 1))

# %%
del x_original
del x_augmented
gc.collect()
# Out:
# 455

# %% [markdown]
# > ### Resized to

# %%
x = tf.image.resize(x, [224,224])

# %%
x = x.numpy() # Before Executing, Change CoLab Hardware Acceleration to None.

# %%
x.shape, y.shape
# Out:
# ((12156, 224, 224, 3), (12156, 1))

# %%
path = '/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/이미지 분류 미니프로젝트/'
with open(path + 'data_x_224.pickle', 'wb') as f:
    pickle.dump(x, f, protocol=4)
with open(path + 'data_y_224.pickle', 'wb') as f:
    pickle.dump(y, f)

# %% [markdown]
# > ### Resized 데이터 불러오기

# %%
path = '/content/drive/MyDrive/Data Science/알파코 딥러닝 부트캠프/프로젝트/이미지 분류 미니프로젝트/'
with open(path + 'data_x_224.pickle', 'rb') as f:
    x = pickle.load(f)
with open(path + 'data_y_224.pickle', 'rb') as f:
    y = pickle.load(f)

# %%
x.shape, y.shape
# Out:
# ((12156, 224, 224, 3), (12156, 1))
